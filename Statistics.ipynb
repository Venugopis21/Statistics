# %% [markdown]
# # Question 1
#
# **Importing the necessary libraries**

# %%
import numpy as npy
import pandas as pds
import seaborn as sea
import matplotlib.pyplot as plot

# %% [markdown]
# # Question 2
#
# **Reading the data as a data frame**

# %%
Data=pds.read_csv('insurance.csv')
Data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # Question 3
#
# **a) Shape of the data**

# %%
Data.shape
# Out:
# (1338, 7)

# %% [markdown]
# **b) Data type of each attribute**

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# **c) Checking the presence of missing values**

# %%
Data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# **d) 5 point summary of numerical attributes**

# %%
Data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# **e) Distribution of ‘bmi’, ‘age’ and ‘charges’ columns**

# %%
sea.distplot(Data['bmi'],color='red')
plot.show()
sea.distplot(Data['age'],color='black')
plot.show()
sea.distplot(Data['charges'],color='purple')
# Out:
# C:\Users\karth\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\karth\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# **f) Measure of skewness of ‘bmi’, ‘age’ and ‘charges’ columns**

# %%
import scipy.stats as pystats
pystats.skew(Data.bmi)
# Out:
# 0.28372857291709386

# %%
pystats.skew(Data.age)
# Out:
# 0.055610083072599126

# %%
pystats.skew(Data.charges)
# Out:
# 1.5141797118745743

# %% [markdown]
# **g) Checking the presence of outliers in ‘bmi’, ‘age’ and ‘charges columns**

# %%
sea.boxplot(Data['bmi'])
# Out:
# C:\Users\karth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bmi'>

# %% [markdown]
# **Number of outliers in bmi**

# %%
Q3=npy.quantile(Data.bmi,0.75)
Q1=npy.quantile(Data.bmi,0.25)
IQR=(Q3)-(Q1)

outlier_bmi = [x for x in Data['bmi'] if x < (Q1-1.5*IQR) or x > (Q3+1.5*IQR)]
len(outlier_bmi)
# Out:
# 9

# %% [markdown]
# **Boxplot Age**

# %%
sea.boxplot(Data['age'])
# Out:
# C:\Users\karth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# **Number of outliers in age**

# %%
Q3=npy.quantile(Data.age,0.75)
Q1=npy.quantile(Data.age,0.25)
IQR=(Q3)-(Q1)

outlier_age = [x for x in Data['age'] if x < (Q1-1.5*IQR) or x > (Q3+1.5*IQR)]
len(outlier_age)
# Out:
# 0

# %% [markdown]
# **Boxplot Charges**

# %%
sea.boxplot(Data['charges'])
# Out:
# C:\Users\karth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='charges'>

# %% [markdown]
# **Number of outliers in charges**

# %%
Q3=npy.quantile(Data.charges,0.75)
Q1=npy.quantile(Data.charges,0.25)
IQR=(Q3)-(Q1)

outlier_charges = [x for x in Data['charges'] if x < (Q1-1.5*IQR) or x > (Q3+1.5*IQR)]
len(outlier_charges)
# Out:
# 139

# %% [markdown]
# **h) Distribution of categorical columns (include children)**

# %%
sea.countplot(Data['sex'])
# Out:
# C:\Users\karth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sea.violinplot(y='charges', x='sex', data=Data, split=True)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='charges'>

# %%
sea.countplot(Data['children'])
# Out:
# C:\Users\karth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='children', ylabel='count'>

# %%
sea.violinplot(y='charges', x='children', data=Data, split=True)
# Out:
# <AxesSubplot:xlabel='children', ylabel='charges'>

# %%
sea.countplot(Data['smoker'])
# Out:
# C:\Users\karth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sea.violinplot(y='charges', x='smoker', data=Data, split=True)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %%
sea.countplot(Data['region'])
# Out:
# C:\Users\karth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
sea.violinplot(y='charges', x='region', data=Data, split=True)
# Out:
# <AxesSubplot:xlabel='region', ylabel='charges'>

# %% [markdown]
# **i) Pair plot that includes all the columns of the data frame**

# %%
from sklearn.preprocessing import LabelEncoder
datadup=Data.copy() 
datadup.loc[:,['sex', 'smoker', 'region']] = Data.loc[:,['sex', 'smoker', 'region']].apply(LabelEncoder().fit_transform)
sea.pairplot(datadup)
plot.show()

# %% [markdown]
# # Question 4
#
# a) Do charges of people who smoke differ from the people who don't?

# %%
plot.figure(figsize=(20,10))
sea.stripplot(y='charges',x='age',hue='smoker',color='blue',data=Data)
plot.show()

# %%
i = npy.array(Data[Data.smoker == 'yes'].charges) 
j= npy.array(Data[Data.smoker == 'no'].charges)

pval = pystats.ttest_ind(i,j, axis = 0)
print(pval)
# Out:
# Ttest_indResult(statistic=46.66492117272371, pvalue=8.271435842179102e-283)

# %% [markdown]
# **b)  Does bmi of males differ significantly from that of females?**

# %%
plot.figure(figsize=(15,12))
sea.stripplot(y='bmi',x='age',hue='sex',color='red',data=Data)
plot.show()

# %%
i = npy.array(Data[Data.sex == 'male'].bmi)  
j= npy.array(Data[Data.sex == 'female'].bmi) 
pval  = stats.ttest_ind(i,j, axis = 0)  
print(pval)
# Out:
# Ttest_indResult(statistic=1.696752635752224, pvalue=0.08997637178984932)

# %% [markdown]
# **c) Is the proportion of smokers significantly different in different genders?**

# %%
crosstab = pds.crosstab(Data['sex'],Data['smoker']) 
chi, pval, dof, expected =  stats.chi2_contingency(crosstab)
print(pval)
# Out:
# 0.006548143503580696

# %% [markdown]
# **d) Is the distribution of bmi across women with no children, one child and two children, the same?**

# %%
dist_f = Data[Data['sex'] == 'female'].copy()
zero = dist_f[dist_f.children == 0]['bmi']
one = dist_f[dist_f.children == 1]['bmi']
two = dist_f[dist_f.children == 2]['bmi']
f_stat, pval= pystats.f_oneway(zero,one,two)
print(pval)
# Out:
# 0.7158579926754841
